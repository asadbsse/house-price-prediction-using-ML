# %% [markdown]
# #### Feature Columns
#
# * id - Unique ID for each home sold
# * date - Date of the home sale
# * price - Price of each home sold
# * bedrooms - Number of bedrooms
# * bathrooms - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * sqft_living - Square footage of the apartments interior living space
# * sqft_lot - Square footage of the land space
# * floors - Number of floors
# * waterfront - A dummy variable for whether the apartment was overlooking the waterfront or not
# * view - An index from 0 to 4 of how good the view of the property was
# * condition - An index from 1 to 5 on the condition of the apartment,
# * grade - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * sqft_above - The square footage of the interior housing space that is above ground level
# * sqft_basement - The square footage of the interior housing space that is below ground level
# * yr_built - The year the house was initially built
# * yr_renovated - The year of the house’s last renovation
# * zipcode - What zipcode area the house is in
# * lat - Lattitude
# * long - Longitude
# * sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# * sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/housesalesprediction/kc_house_data.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %%
plt.figure(figsize=(12,8))
sns.displot(df['price'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(df['bedrooms'])
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# ### Geographical Properties

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# 19017  2303900100  20140911T000000  3800000.0         3       4.25
# 7035    853200010  20140701T000000  3800000.0         5       5.50
# 16302  7397300170  20140530T000000  3710000.0         4       3.50
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# 18482  4389201095  20150511T000000  3650000.0         5       3.75
# 15255  2425049063  20140911T000000  3640900.0         4       3.25
# 19148  3625049042  20141011T000000  3635000.0         5       6.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# 3914         10040     37325     2.0           1     2  ...     11
# 9254          9890     31374     2.0           0     4  ...     13
# 4411          9200     35069     2.0           0     0  ...     13
# 1448          8000     23985     2.0           0     4  ...     12
# 1315          7390     24829     2.0           1     4  ...     12
# 1164          8010     45517     2.0           1     4  ...     12
# 8092          9640     13068     1.0           1     4  ...     12
# 2626          6640     40014     2.0           1     4  ...     12
# 8638          6430     27517     2.0           0     0  ...     12
# 12370         7440     21540     2.0           0     0  ...     12
# 4149          7080     16573     2.0           0     0  ...     12
# 2085          5770     21300     2.0           1     4  ...     11
# 19017         5510     35000     2.0           0     4  ...     13
# 7035          7050     42840     1.0           0     2  ...     13
# 16302         5550     28078     2.0           0     2  ...     12
# 6508          5480     19401     1.5           1     4  ...     11
# 18482         5020      8694     2.0           0     1  ...     12
# 15255         4830     22257     2.0           1     4  ...     11
# 19148         5490     19897     2.0           0     0  ...     12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 7252         8570           3480      1910          1987    98102  47.6298
# 3914         7680           2360      1940          2001    98004  47.6500
# 9254         8860           1030      2001             0    98039  47.6305
# 4411         6200           3000      2001             0    98039  47.6289
# 1448         6720           1280      2009             0    98004  47.6232
# 1315         5000           2390      1991             0    98040  47.5631
# 1164         5990           2020      1999             0    98033  47.6767
# 8092         4820           4820      1983          2009    98040  47.5570
# 2626         6350            290      2004             0    98155  47.7493
# 8638         6430              0      2001             0    98004  47.6208
# 12370        5550           1890      2003             0    98006  47.5692
# 4149         5760           1320      2008             0    98039  47.6151
# 2085         5770              0      1980             0    98040  47.5850
# 19017        4910            600      1997             0    98177  47.7296
# 7035         4320           2730      1978             0    98004  47.6229
# 16302        3350           2200      2000             0    98039  47.6395
# 6508         3910           1570      1936             0    98105  47.6515
# 18482        3970           1050      2007             0    98004  47.6146
# 15255        4830              0      1990             0    98039  47.6409
# 19148        5490              0      2005             0    98039  47.6165
#
#           long  sqft_living15  sqft_lot15
# 7252  -122.323           3940        8800
# 3914  -122.214           3930       25449
# 9254  -122.240           4540       42730
# 4411  -122.233           3560       24345
# 1448  -122.220           4600       21750
# 1315  -122.210           4320       24619
# 1164  -122.211           3430       26788
# 8092  -122.210           3270       10454
# 2626  -122.280           3030       23408
# 8638  -122.219           3720       14592
# 12370 -122.189           4740       19329
# 4149  -122.224           3140       15996
# 2085  -122.222           4620       22748
# 19017 -122.370           3430       45302
# 7035  -122.220           5070       20570
# 16302 -122.234           2980       19602
# 6508  -122.277           3510       15810
# 18482 -122.213           4190       11275
# 15255 -122.241           3820       25582
# 19148 -122.236           2910       17600
#
# [20 rows x 21 columns]

# %%
len(df)*(0.01)
# Out:
# 216.13

# %%
non_top_1_perc = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',
                data=non_top_1_perc,hue='price',
                palette='RdYlGn',edgecolor=None,alpha=0.2)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# ### Other Features

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ## Working with Feature Data

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
df = df.drop('id',axis=1)

# %%
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %% [markdown]
# ### Feature Engineering from Date

# %%
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].apply(lambda date:date.month)
df['year'] = df['date'].apply(lambda date:date.year)
sns.boxplot(x='year',y='price',data=df)
sns.boxplot(x='month',y='price',data=df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df = df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'month', 'year'],
#       dtype='object')

# %%
df['zipcode'].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %%
df = df.drop('zipcode',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year
# 0  47.5112 -122.257           1340        5650     10  2014
# 1  47.7210 -122.319           1690        7639     12  2014
# 2  47.7379 -122.233           2720        8062      2  2015
# 3  47.5208 -122.393           1360        5000     12  2014
# 4  47.6168 -122.045           1800        7503      2  2015

# %%
# could make sense due to scaling, higher should correlate to more value
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0      13126
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: count, Length: 306, dtype: int64

# %% [markdown]
# ## Scaling and Train Test Split

# %%
X = df.drop('price', axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Scale the features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %% [markdown]
# ## Creating a Model

# %%
X_train
# Out:
# array([[[0.09090909, 0.21875   , 0.11245283, ..., 0.01429443,
#          0.36363636, 0.        ]],
#
#        [[0.06060606, 0.125     , 0.05358491, ..., 0.0049957 ,
#          0.18181818, 1.        ]],
#
#        [[0.09090909, 0.125     , 0.05962264, ..., 0.00821206,
#          0.09090909, 1.        ]],
#
#        ...,
#
#        [[0.09090909, 0.3125    , 0.13811321, ..., 0.00229625,
#          0.72727273, 0.        ]],
#
#        [[0.03030303, 0.09375   , 0.00679245, ..., 0.0164827 ,
#          0.45454545, 0.        ]],
#
#        [[0.12121212, 0.3125    , 0.21433962, ..., 0.00614095,
#          0.18181818, 1.        ]]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Dropout, Dense, Input, Concatenate, BatchNormalization, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define input layer
input_layer = Input(shape=(1, X_train.shape[2]))

# LSTM layers
lstm_1 = LSTM(64, activation='tanh', return_sequences=True)(input_layer)
lstm_1 = BatchNormalization()(lstm_1)
lstm_1 = Dropout(0.3)(lstm_1)

lstm_2 = LSTM(32, activation='tanh', return_sequences=True)(lstm_1)
lstm_2 = BatchNormalization()(lstm_2)
lstm_2 = Dropout(0.3)(lstm_2)

lstm_3 = LSTM(16, activation='tanh')(lstm_2)
lstm_3 = BatchNormalization()(lstm_3)
lstm_3 = Dropout(0.3)(lstm_3)

# Dense layers
#dense_1 = Dense(64, activation='relu')(input_layer)
#dense_1 = BatchNormalization()(dense_1)
#dense_1 = Dropout(0.3)(dense_1)


#dense_2 = Dense(32, activation='relu')(dense_1)
#dense_2 = BatchNormalization()(dense_2)
#dense_2 = Dropout(0.3)(dense_2)

#dense_3 = Dense(16, activation='relu')(dense_2)
#dense_3 = BatchNormalization()(dense_3)
#dense_3 = Dropout(0.3)(dense_3)
#dense_3_reshaped = Reshape((16,))(dense_3)  # Reshape to match LSTM output

 #Concatenate LSTM output and dense layer output
#concatenated_layer = Concatenate()([lstm_3, dense_3_reshaped])

# Fully connected layers
fc_1 = Dense(32, activation='relu')(lstm_3)
fc_1 = BatchNormalization()(fc_1)

output_layer = Dense(1)(fc_1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model with an optimized learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse')

# Implement learning rate reduction
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# %%
# Fit the model with more verbose output for monitoring
history = model.fit(X_train, y_train, epochs=400, batch_size=128, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/400
# 136/136 [==============================] - 13s 25ms/step - loss: 0.4437 - val_loss: 0.0298
# Epoch 2/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0756 - val_loss: 0.0097
# Epoch 3/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0363 - val_loss: 0.0048
# Epoch 4/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0217 - val_loss: 0.0060
# Epoch 5/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0155 - val_loss: 0.0058
# Epoch 6/400
# 136/136 [==============================] - 2s 11ms/step - loss: 0.0123 - val_loss: 0.0056
# Epoch 7/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0097 - val_loss: 0.0039
# Epoch 8/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0080 - val_loss: 0.0034
# Epoch 9/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0069 - val_loss: 0.0031
# Epoch 10/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0029
# Epoch 11/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 12/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 13/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 14/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 15/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 16/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 17/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 18/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 19/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 20/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 21/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 22/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 23/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 24/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 25/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 26/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 27/400
# 136/136 [==============================] - 2s 11ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 28/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 29/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 30/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 31/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 32/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 33/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 34/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 35/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0013 - val_loss: 9.4254e-04
# Epoch 36/400
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0013 - val_loss: 9.1814e-04
# Epoch 37/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0013 - val_loss: 9.1865e-04
# Epoch 38/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 39/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0012 - val_loss: 8.8011e-04
# Epoch 40/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0012 - val_loss: 9.1696e-04
# Epoch 41/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0012 - val_loss: 8.1988e-04
# Epoch 42/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0012 - val_loss: 8.3653e-04
# Epoch 43/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0011 - val_loss: 8.1971e-04
# Epoch 44/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0011 - val_loss: 8.4462e-04
# Epoch 45/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0011 - val_loss: 8.4630e-04
# Epoch 46/400
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0011 - val_loss: 7.9294e-04
# Epoch 47/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 8.2684e-04
# Epoch 48/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 8.1693e-04
# Epoch 49/400
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 50/400
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0010 - val_loss: 8.1308e-04
# Epoch 51/400
# 136/136 [==============================] - 2s 13ms/step - loss: 9.7876e-04 - val_loss: 7.5874e-04
# Epoch 52/400
# 136/136 [==============================] - 2s 13ms/step - loss: 9.9851e-04 - val_loss: 7.9694e-04
# Epoch 53/400
# 136/136 [==============================] - 2s 13ms/step - loss: 9.5020e-04 - val_loss: 8.0833e-04
# Epoch 54/400
# 136/136 [==============================] - 2s 12ms/step - loss: 9.7024e-04 - val_loss: 8.3291e-04
# Epoch 55/400
# 136/136 [==============================] - 2s 14ms/step - loss: 9.8491e-04 - val_loss: 8.7640e-04
# Epoch 56/400
# 136/136 [==============================] - 2s 12ms/step - loss: 9.2459e-04 - val_loss: 6.6858e-04
# Epoch 57/400
# 136/136 [==============================] - 2s 13ms/step - loss: 9.2938e-04 - val_loss: 7.8052e-04
# Epoch 58/400
# 136/136 [==============================] - 2s 14ms/step - loss: 9.2947e-04 - val_loss: 7.6109e-04
# Epoch 59/400
# 136/136 [==============================] - 2s 14ms/step - loss: 8.9511e-04 - val_loss: 7.0642e-04
# Epoch 60/400
# 136/136 [==============================] - 2s 13ms/step - loss: 9.0895e-04 - val_loss: 7.1513e-04
# Epoch 61/400
# 136/136 [==============================] - 2s 13ms/step - loss: 8.9544e-04 - val_loss: 8.1401e-04
# Epoch 62/400
# 136/136 [==============================] - 2s 13ms/step - loss: 8.7734e-04 - val_loss: 7.2386e-04
# Epoch 63/400
# 136/136 [==============================] - 2s 14ms/step - loss: 8.7680e-04 - val_loss: 5.7641e-04
# Epoch 64/400
# 136/136 [==============================] - 2s 14ms/step - loss: 8.5859e-04 - val_loss: 9.1611e-04
# Epoch 65/400
# 136/136 [==============================] - 2s 13ms/step - loss: 8.1737e-04 - val_loss: 6.3764e-04
# Epoch 66/400
# 136/136 [==============================] - 2s 13ms/step - loss: 8.2059e-04 - val_loss: 8.3207e-04
# Epoch 67/400
# 136/136 [==============================] - 2s 14ms/step - loss: 8.2441e-04 - val_loss: 5.7393e-04
# Epoch 68/400
# 136/136 [==============================] - 2s 12ms/step - loss: 8.2713e-04 - val_loss: 6.8343e-04
# Epoch 69/400
# 136/136 [==============================] - 2s 13ms/step - loss: 8.0128e-04 - val_loss: 6.4152e-04
# Epoch 70/400
# 136/136 [==============================] - 2s 13ms/step - loss: 7.6240e-04 - val_loss: 6.8032e-04
# Epoch 71/400
# 136/136 [==============================] - 2s 14ms/step - loss: 7.9163e-04 - val_loss: 8.2827e-04
# Epoch 72/400
# 136/136 [==============================] - 2s 13ms/step - loss: 7.8921e-04 - val_loss: 5.6886e-04
# Epoch 73/400
# 136/136 [==============================] - 2s 14ms/step - loss: 7.3789e-04 - val_loss: 4.9105e-04
# Epoch 74/400
# 136/136 [==============================] - 2s 13ms/step - loss: 7.6087e-04 - val_loss: 6.4076e-04
# Epoch 75/400
# 136/136 [==============================] - 2s 14ms/step - loss: 7.7116e-04 - val_loss: 6.8947e-04
# Epoch 76/400
# 136/136 [==============================] - 2s 13ms/step - loss: 7.3985e-04 - val_loss: 5.1505e-04
# Epoch 77/400
# 136/136 [==============================] - 2s 13ms/step - loss: 7.3713e-04 - val_loss: 6.1983e-04
# Epoch 78/400
# 136/136 [==============================] - 2s 13ms/step - loss: 7.1913e-04 - val_loss: 6.1686e-04
# Epoch 79/400
# 136/136 [==============================] - 2s 12ms/step - loss: 7.3155e-04 - val_loss: 5.0491e-04
# Epoch 80/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.9209e-04 - val_loss: 5.4243e-04
# Epoch 81/400
# 136/136 [==============================] - 2s 14ms/step - loss: 7.1198e-04 - val_loss: 5.7194e-04
# Epoch 82/400
# 136/136 [==============================] - 2s 14ms/step - loss: 6.7108e-04 - val_loss: 5.6239e-04
# Epoch 83/400
# 136/136 [==============================] - 2s 14ms/step - loss: 6.9080e-04 - val_loss: 5.1333e-04
# Epoch 84/400
# 136/136 [==============================] - 2s 15ms/step - loss: 6.4024e-04 - val_loss: 8.3709e-04
# Epoch 85/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.5990e-04 - val_loss: 5.0204e-04
# Epoch 86/400
# 136/136 [==============================] - 2s 14ms/step - loss: 6.5535e-04 - val_loss: 5.5376e-04
# Epoch 87/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.5226e-04 - val_loss: 5.7964e-04
# Epoch 88/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.6167e-04 - val_loss: 4.8675e-04
# Epoch 89/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.1341e-04 - val_loss: 5.5954e-04
# Epoch 90/400
# 136/136 [==============================] - 2s 14ms/step - loss: 6.4623e-04 - val_loss: 5.9803e-04
# Epoch 91/400
# 136/136 [==============================] - 2s 16ms/step - loss: 6.2207e-04 - val_loss: 4.3728e-04
# Epoch 92/400
# 136/136 [==============================] - 2s 15ms/step - loss: 6.4481e-04 - val_loss: 7.0126e-04
# Epoch 93/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.1673e-04 - val_loss: 4.4218e-04
# Epoch 94/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.0891e-04 - val_loss: 5.5633e-04
# Epoch 95/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.2389e-04 - val_loss: 4.4790e-04
# Epoch 96/400
# 136/136 [==============================] - 2s 14ms/step - loss: 6.1812e-04 - val_loss: 5.0716e-04
# Epoch 97/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.5857e-04 - val_loss: 6.0471e-04
# Epoch 98/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.0955e-04 - val_loss: 5.3735e-04
# Epoch 99/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.9825e-04 - val_loss: 5.9260e-04
# Epoch 100/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.9346e-04 - val_loss: 5.0706e-04
# Epoch 101/400
# 136/136 [==============================] - 2s 13ms/step - loss: 6.2635e-04 - val_loss: 5.2854e-04
# Epoch 102/400
# 136/136 [==============================] - 2s 15ms/step - loss: 5.5691e-04 - val_loss: 5.2556e-04
# Epoch 103/400
# 136/136 [==============================] - 2s 15ms/step - loss: 5.7331e-04 - val_loss: 6.8952e-04
# Epoch 104/400
# 136/136 [==============================] - 2s 15ms/step - loss: 5.6435e-04 - val_loss: 8.7657e-04
# Epoch 105/400
# 136/136 [==============================] - 2s 14ms/step - loss: 5.6785e-04 - val_loss: 5.1113e-04
# Epoch 106/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.9814e-04 - val_loss: 4.9081e-04
# Epoch 107/400
# 136/136 [==============================] - 2s 12ms/step - loss: 5.3308e-04 - val_loss: 4.8397e-04
# Epoch 108/400
# 136/136 [==============================] - 2s 12ms/step - loss: 6.2090e-04 - val_loss: 4.6057e-04
# Epoch 109/400
# 136/136 [==============================] - 2s 12ms/step - loss: 5.2963e-04 - val_loss: 5.9121e-04
# Epoch 110/400
# 136/136 [==============================] - 2s 12ms/step - loss: 5.5229e-04 - val_loss: 4.0241e-04
# Epoch 111/400
# 136/136 [==============================] - 2s 14ms/step - loss: 7.2603e-04 - val_loss: 4.6881e-04
# Epoch 112/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.1432e-04 - val_loss: 5.0125e-04
# Epoch 113/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.3911e-04 - val_loss: 4.9168e-04
# Epoch 114/400
# 136/136 [==============================] - 2s 14ms/step - loss: 5.1850e-04 - val_loss: 4.5789e-04
# Epoch 115/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.8720e-04 - val_loss: 6.3123e-04
# Epoch 116/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.1402e-04 - val_loss: 4.6599e-04
# Epoch 117/400
# 136/136 [==============================] - 2s 15ms/step - loss: 5.2822e-04 - val_loss: 6.9537e-04
# Epoch 118/400
# 136/136 [==============================] - 2s 15ms/step - loss: 5.3353e-04 - val_loss: 5.5009e-04
# Epoch 119/400
# 136/136 [==============================] - 2s 14ms/step - loss: 5.5997e-04 - val_loss: 5.2407e-04
# Epoch 120/400
# 136/136 [==============================] - 2s 14ms/step - loss: 5.1990e-04 - val_loss: 5.8041e-04
# Epoch 121/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.3655e-04 - val_loss: 4.1345e-04
# Epoch 122/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.0501e-04 - val_loss: 7.5875e-04
# Epoch 123/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.9648e-04 - val_loss: 6.1072e-04
# Epoch 124/400
# 136/136 [==============================] - 2s 15ms/step - loss: 4.6871e-04 - val_loss: 5.3366e-04
# Epoch 125/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.8821e-04 - val_loss: 4.2554e-04
# Epoch 126/400
# 136/136 [==============================] - 2s 14ms/step - loss: 5.3522e-04 - val_loss: 4.6820e-04
# Epoch 127/400
# 136/136 [==============================] - 2s 15ms/step - loss: 4.9743e-04 - val_loss: 3.9570e-04
# Epoch 128/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.6288e-04 - val_loss: 4.3009e-04
# Epoch 129/400
# 136/136 [==============================] - 2s 15ms/step - loss: 4.9827e-04 - val_loss: 3.7945e-04
# Epoch 130/400
# 136/136 [==============================] - 2s 14ms/step - loss: 5.0882e-04 - val_loss: 5.1097e-04
# Epoch 131/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.2264e-04 - val_loss: 5.9631e-04
# Epoch 132/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.0469e-04 - val_loss: 4.3854e-04
# Epoch 133/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.8956e-04 - val_loss: 6.0741e-04
# Epoch 134/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.8998e-04 - val_loss: 4.0905e-04
# Epoch 135/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.8935e-04 - val_loss: 5.2989e-04
# Epoch 136/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.0520e-04 - val_loss: 5.4265e-04
# Epoch 137/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.8983e-04 - val_loss: 5.1102e-04
# Epoch 138/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.6334e-04 - val_loss: 4.4650e-04
# Epoch 139/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.9462e-04 - val_loss: 6.5936e-04
# Epoch 140/400
# 136/136 [==============================] - 2s 12ms/step - loss: 5.0035e-04 - val_loss: 4.2320e-04
# Epoch 141/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.8825e-04 - val_loss: 5.4541e-04
# Epoch 142/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.7407e-04 - val_loss: 4.4652e-04
# Epoch 143/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.8339e-04 - val_loss: 5.4127e-04
# Epoch 144/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.7525e-04 - val_loss: 3.8049e-04
# Epoch 145/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.9367e-04 - val_loss: 5.2058e-04
# Epoch 146/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.8777e-04 - val_loss: 6.1427e-04
# Epoch 147/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.8995e-04 - val_loss: 4.8680e-04
# Epoch 148/400
# 136/136 [==============================] - 2s 12ms/step - loss: 5.0399e-04 - val_loss: 3.7550e-04
# Epoch 149/400
# 136/136 [==============================] - 2s 12ms/step - loss: 5.2239e-04 - val_loss: 5.3822e-04
# Epoch 150/400
# 136/136 [==============================] - 2s 13ms/step - loss: 5.2066e-04 - val_loss: 4.5442e-04
# Epoch 151/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.7729e-04 - val_loss: 4.5755e-04
# Epoch 152/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.7301e-04 - val_loss: 5.9876e-04
# Epoch 153/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.5610e-04 - val_loss: 5.1668e-04
# Epoch 154/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.3628e-04 - val_loss: 5.2863e-04
# Epoch 155/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.9027e-04 - val_loss: 5.7562e-04
# Epoch 156/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4634e-04 - val_loss: 4.2664e-04
# Epoch 157/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.5812e-04 - val_loss: 4.2426e-04
# Epoch 158/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.3743e-04 - val_loss: 4.5015e-04
# Epoch 159/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4446e-04 - val_loss: 5.3393e-04
# Epoch 160/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4124e-04 - val_loss: 5.8462e-04
# Epoch 161/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4821e-04 - val_loss: 5.9456e-04
# Epoch 162/400
# 136/136 [==============================] - 2s 11ms/step - loss: 4.2324e-04 - val_loss: 4.9904e-04
# Epoch 163/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.3393e-04 - val_loss: 6.7391e-04
# Epoch 164/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.7454e-04 - val_loss: 4.5468e-04
# Epoch 165/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.5732e-04 - val_loss: 5.0342e-04
# Epoch 166/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.5594e-04 - val_loss: 6.1307e-04
# Epoch 167/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.5887e-04 - val_loss: 4.8709e-04
# Epoch 168/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.3633e-04 - val_loss: 3.9976e-04
# Epoch 169/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4237e-04 - val_loss: 4.4803e-04
# Epoch 170/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.7175e-04 - val_loss: 3.9901e-04
# Epoch 171/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.4972e-04 - val_loss: 4.6674e-04
# Epoch 172/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.7272e-04 - val_loss: 6.3473e-04
# Epoch 173/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.3316e-04 - val_loss: 5.2942e-04
# Epoch 174/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4914e-04 - val_loss: 6.3530e-04
# Epoch 175/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.6031e-04 - val_loss: 4.3949e-04
# Epoch 176/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.6764e-04 - val_loss: 4.5918e-04
# Epoch 177/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.3522e-04 - val_loss: 6.2631e-04
# Epoch 178/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.5200e-04 - val_loss: 4.2223e-04
# Epoch 179/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4191e-04 - val_loss: 4.1142e-04
# Epoch 180/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.2747e-04 - val_loss: 3.6378e-04
# Epoch 181/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4642e-04 - val_loss: 4.1563e-04
# Epoch 182/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.3678e-04 - val_loss: 7.4150e-04
# Epoch 183/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2320e-04 - val_loss: 3.7258e-04
# Epoch 184/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4177e-04 - val_loss: 6.3488e-04
# Epoch 185/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.1723e-04 - val_loss: 4.5935e-04
# Epoch 186/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.3802e-04 - val_loss: 4.3776e-04
# Epoch 187/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.1663e-04 - val_loss: 4.7694e-04
# Epoch 188/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.1337e-04 - val_loss: 4.5184e-04
# Epoch 189/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.1949e-04 - val_loss: 6.9559e-04
# Epoch 190/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.0138e-04 - val_loss: 4.4710e-04
# Epoch 191/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2076e-04 - val_loss: 4.3877e-04
# Epoch 192/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.3138e-04 - val_loss: 3.8653e-04
# Epoch 193/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.2715e-04 - val_loss: 5.2343e-04
# Epoch 194/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4349e-04 - val_loss: 3.8269e-04
# Epoch 195/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.1365e-04 - val_loss: 4.2689e-04
# Epoch 196/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.2504e-04 - val_loss: 5.0598e-04
# Epoch 197/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2908e-04 - val_loss: 4.9693e-04
# Epoch 198/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2887e-04 - val_loss: 4.3593e-04
# Epoch 199/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9523e-04 - val_loss: 4.2948e-04
# Epoch 200/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.3688e-04 - val_loss: 4.9392e-04
# Epoch 201/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.4186e-04 - val_loss: 4.6527e-04
# Epoch 202/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.0322e-04 - val_loss: 4.7710e-04
# Epoch 203/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.4576e-04 - val_loss: 5.8347e-04
# Epoch 204/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2173e-04 - val_loss: 5.3666e-04
# Epoch 205/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.1796e-04 - val_loss: 5.1966e-04
# Epoch 206/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.1726e-04 - val_loss: 5.6251e-04
# Epoch 207/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2504e-04 - val_loss: 4.7180e-04
# Epoch 208/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.1468e-04 - val_loss: 3.8981e-04
# Epoch 209/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.1888e-04 - val_loss: 4.9044e-04
# Epoch 210/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9692e-04 - val_loss: 5.1062e-04
# Epoch 211/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.1974e-04 - val_loss: 4.7998e-04
# Epoch 212/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.0433e-04 - val_loss: 4.7086e-04
# Epoch 213/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.1107e-04 - val_loss: 5.8411e-04
# Epoch 214/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.2621e-04 - val_loss: 5.9821e-04
# Epoch 215/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.0216e-04 - val_loss: 6.3418e-04
# Epoch 216/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.2598e-04 - val_loss: 4.3094e-04
# Epoch 217/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4214e-04 - val_loss: 4.4081e-04
# Epoch 218/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.0888e-04 - val_loss: 4.6324e-04
# Epoch 219/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.0701e-04 - val_loss: 5.0050e-04
# Epoch 220/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9701e-04 - val_loss: 5.3859e-04
# Epoch 221/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9494e-04 - val_loss: 6.7585e-04
# Epoch 222/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9327e-04 - val_loss: 7.0565e-04
# Epoch 223/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.2422e-04 - val_loss: 6.5712e-04
# Epoch 224/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2079e-04 - val_loss: 5.1002e-04
# Epoch 225/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.0149e-04 - val_loss: 4.1239e-04
# Epoch 226/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.9957e-04 - val_loss: 5.1056e-04
# Epoch 227/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.0032e-04 - val_loss: 4.3760e-04
# Epoch 228/400
# 136/136 [==============================] - 2s 11ms/step - loss: 4.0003e-04 - val_loss: 5.4733e-04
# Epoch 229/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.8566e-04 - val_loss: 5.9901e-04
# Epoch 230/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2425e-04 - val_loss: 5.5282e-04
# Epoch 231/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.1323e-04 - val_loss: 5.7001e-04
# Epoch 232/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.0806e-04 - val_loss: 4.0654e-04
# Epoch 233/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.0448e-04 - val_loss: 8.7130e-04
# Epoch 234/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2647e-04 - val_loss: 4.9459e-04
# Epoch 235/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.7402e-04 - val_loss: 5.5819e-04
# Epoch 236/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2338e-04 - val_loss: 4.4614e-04
# Epoch 237/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9618e-04 - val_loss: 4.2085e-04
# Epoch 238/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9456e-04 - val_loss: 4.2397e-04
# Epoch 239/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.7678e-04 - val_loss: 5.2484e-04
# Epoch 240/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.2941e-04 - val_loss: 5.0005e-04
# Epoch 241/400
# 136/136 [==============================] - 2s 12ms/step - loss: 4.4195e-04 - val_loss: 4.7813e-04
# Epoch 242/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9251e-04 - val_loss: 5.5449e-04
# Epoch 243/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9952e-04 - val_loss: 6.3431e-04
# Epoch 244/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.1232e-04 - val_loss: 6.4625e-04
# Epoch 245/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9147e-04 - val_loss: 5.5232e-04
# Epoch 246/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.7212e-04 - val_loss: 5.4156e-04
# Epoch 247/400
# 136/136 [==============================] - 2s 14ms/step - loss: 4.0370e-04 - val_loss: 4.6539e-04
# Epoch 248/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.8134e-04 - val_loss: 4.8777e-04
# Epoch 249/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.8830e-04 - val_loss: 5.3863e-04
# Epoch 250/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.8148e-04 - val_loss: 5.7161e-04
# Epoch 251/400
# 136/136 [==============================] - 2s 15ms/step - loss: 4.1507e-04 - val_loss: 6.3785e-04
# Epoch 252/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.8133e-04 - val_loss: 5.8153e-04
# Epoch 253/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.9787e-04 - val_loss: 5.9606e-04
# Epoch 254/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.9582e-04 - val_loss: 4.8816e-04
# Epoch 255/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9730e-04 - val_loss: 4.9126e-04
# Epoch 256/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9654e-04 - val_loss: 5.1715e-04
# Epoch 257/400
# 136/136 [==============================] - 2s 17ms/step - loss: 3.6863e-04 - val_loss: 4.8781e-04
# Epoch 258/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7570e-04 - val_loss: 6.1385e-04
# Epoch 259/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.6884e-04 - val_loss: 4.6131e-04
# Epoch 260/400
# 136/136 [==============================] - 2s 16ms/step - loss: 3.6156e-04 - val_loss: 5.1865e-04
# Epoch 261/400
# 136/136 [==============================] - 2s 15ms/step - loss: 4.0419e-04 - val_loss: 6.4981e-04
# Epoch 262/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.8032e-04 - val_loss: 5.9951e-04
# Epoch 263/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.8047e-04 - val_loss: 5.9607e-04
# Epoch 264/400
# 136/136 [==============================] - 2s 13ms/step - loss: 4.1161e-04 - val_loss: 7.2137e-04
# Epoch 265/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.8286e-04 - val_loss: 6.0592e-04
# Epoch 266/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.8170e-04 - val_loss: 4.0500e-04
# Epoch 267/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.6354e-04 - val_loss: 5.1227e-04
# Epoch 268/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9469e-04 - val_loss: 6.9582e-04
# Epoch 269/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.6838e-04 - val_loss: 5.1637e-04
# Epoch 270/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.8365e-04 - val_loss: 8.5578e-04
# Epoch 271/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.8952e-04 - val_loss: 7.3395e-04
# Epoch 272/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.6735e-04 - val_loss: 5.5755e-04
# Epoch 273/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7129e-04 - val_loss: 5.9564e-04
# Epoch 274/400
# 136/136 [==============================] - 2s 16ms/step - loss: 3.8528e-04 - val_loss: 4.7232e-04
# Epoch 275/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7356e-04 - val_loss: 6.3416e-04
# Epoch 276/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.7952e-04 - val_loss: 5.4556e-04
# Epoch 277/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5759e-04 - val_loss: 5.3577e-04
# Epoch 278/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.7139e-04 - val_loss: 6.5248e-04
# Epoch 279/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.5598e-04 - val_loss: 6.1784e-04
# Epoch 280/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.6427e-04 - val_loss: 5.7477e-04
# Epoch 281/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.4230e-04 - val_loss: 5.8875e-04
# Epoch 282/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9869e-04 - val_loss: 5.7992e-04
# Epoch 283/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9388e-04 - val_loss: 4.3805e-04
# Epoch 284/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7885e-04 - val_loss: 5.2407e-04
# Epoch 285/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.6739e-04 - val_loss: 5.9365e-04
# Epoch 286/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7553e-04 - val_loss: 5.9137e-04
# Epoch 287/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.9411e-04 - val_loss: 3.9024e-04
# Epoch 288/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.8926e-04 - val_loss: 3.8391e-04
# Epoch 289/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7623e-04 - val_loss: 5.4903e-04
# Epoch 290/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.5531e-04 - val_loss: 4.7472e-04
# Epoch 291/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.5413e-04 - val_loss: 4.5944e-04
# Epoch 292/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.6779e-04 - val_loss: 4.2880e-04
# Epoch 293/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.8208e-04 - val_loss: 6.1395e-04
# Epoch 294/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.7781e-04 - val_loss: 4.9490e-04
# Epoch 295/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.7105e-04 - val_loss: 5.2979e-04
# Epoch 296/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.5742e-04 - val_loss: 6.1393e-04
# Epoch 297/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.5555e-04 - val_loss: 4.0759e-04
# Epoch 298/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.5943e-04 - val_loss: 5.0704e-04
# Epoch 299/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.6322e-04 - val_loss: 5.3044e-04
# Epoch 300/400
# 136/136 [==============================] - 2s 16ms/step - loss: 3.6048e-04 - val_loss: 4.6022e-04
# Epoch 301/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.6904e-04 - val_loss: 5.8834e-04
# Epoch 302/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7565e-04 - val_loss: 5.8680e-04
# Epoch 303/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5454e-04 - val_loss: 5.1817e-04
# Epoch 304/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.6818e-04 - val_loss: 6.0695e-04
# Epoch 305/400
# 136/136 [==============================] - 2s 16ms/step - loss: 3.7122e-04 - val_loss: 6.0654e-04
# Epoch 306/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.6049e-04 - val_loss: 6.0817e-04
# Epoch 307/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.6686e-04 - val_loss: 6.0065e-04
# Epoch 308/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.9474e-04 - val_loss: 5.8736e-04
# Epoch 309/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4010e-04 - val_loss: 5.0386e-04
# Epoch 310/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.3894e-04 - val_loss: 6.1164e-04
# Epoch 311/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.5908e-04 - val_loss: 5.5407e-04
# Epoch 312/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.9818e-04 - val_loss: 5.3091e-04
# Epoch 313/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5966e-04 - val_loss: 5.3988e-04
# Epoch 314/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.4297e-04 - val_loss: 5.2970e-04
# Epoch 315/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4734e-04 - val_loss: 5.1477e-04
# Epoch 316/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7413e-04 - val_loss: 6.0948e-04
# Epoch 317/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5804e-04 - val_loss: 6.1062e-04
# Epoch 318/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5360e-04 - val_loss: 5.2410e-04
# Epoch 319/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5897e-04 - val_loss: 5.5116e-04
# Epoch 320/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.8061e-04 - val_loss: 5.9484e-04
# Epoch 321/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3554e-04 - val_loss: 6.7365e-04
# Epoch 322/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5699e-04 - val_loss: 6.2231e-04
# Epoch 323/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4647e-04 - val_loss: 5.5366e-04
# Epoch 324/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5232e-04 - val_loss: 6.5223e-04
# Epoch 325/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.6690e-04 - val_loss: 4.9485e-04
# Epoch 326/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4101e-04 - val_loss: 5.0900e-04
# Epoch 327/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4057e-04 - val_loss: 5.8855e-04
# Epoch 328/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.7819e-04 - val_loss: 6.6115e-04
# Epoch 329/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.6591e-04 - val_loss: 5.2374e-04
# Epoch 330/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5962e-04 - val_loss: 4.3244e-04
# Epoch 331/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4222e-04 - val_loss: 5.3509e-04
# Epoch 332/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4338e-04 - val_loss: 4.9388e-04
# Epoch 333/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4906e-04 - val_loss: 8.6987e-04
# Epoch 334/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5636e-04 - val_loss: 5.6221e-04
# Epoch 335/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4556e-04 - val_loss: 7.6632e-04
# Epoch 336/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.6266e-04 - val_loss: 6.9263e-04
# Epoch 337/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.3480e-04 - val_loss: 6.1879e-04
# Epoch 338/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3015e-04 - val_loss: 5.1744e-04
# Epoch 339/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5444e-04 - val_loss: 5.7136e-04
# Epoch 340/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5485e-04 - val_loss: 5.5477e-04
# Epoch 341/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.7502e-04 - val_loss: 7.1113e-04
# Epoch 342/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5045e-04 - val_loss: 4.0870e-04
# Epoch 343/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5540e-04 - val_loss: 5.8345e-04
# Epoch 344/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5105e-04 - val_loss: 6.4555e-04
# Epoch 345/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3367e-04 - val_loss: 6.5818e-04
# Epoch 346/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.2939e-04 - val_loss: 6.9377e-04
# Epoch 347/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5016e-04 - val_loss: 5.8150e-04
# Epoch 348/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.7074e-04 - val_loss: 5.1713e-04
# Epoch 349/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.6662e-04 - val_loss: 3.8192e-04
# Epoch 350/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.4978e-04 - val_loss: 5.1737e-04
# Epoch 351/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.2962e-04 - val_loss: 3.7190e-04
# Epoch 352/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4124e-04 - val_loss: 5.0631e-04
# Epoch 353/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5749e-04 - val_loss: 6.2749e-04
# Epoch 354/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.6410e-04 - val_loss: 4.8698e-04
# Epoch 355/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4080e-04 - val_loss: 4.5885e-04
# Epoch 356/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4271e-04 - val_loss: 3.3211e-04
# Epoch 357/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.4067e-04 - val_loss: 5.7333e-04
# Epoch 358/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4647e-04 - val_loss: 6.5177e-04
# Epoch 359/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4395e-04 - val_loss: 5.2163e-04
# Epoch 360/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.4293e-04 - val_loss: 4.9493e-04
# Epoch 361/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4105e-04 - val_loss: 6.2266e-04
# Epoch 362/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.5418e-04 - val_loss: 5.0315e-04
# Epoch 363/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.3413e-04 - val_loss: 6.7359e-04
# Epoch 364/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.2775e-04 - val_loss: 6.8424e-04
# Epoch 365/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3326e-04 - val_loss: 7.8486e-04
# Epoch 366/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.7350e-04 - val_loss: 4.9329e-04
# Epoch 367/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3884e-04 - val_loss: 5.7435e-04
# Epoch 368/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.3188e-04 - val_loss: 5.3337e-04
# Epoch 369/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.1884e-04 - val_loss: 5.2462e-04
# Epoch 370/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.6754e-04 - val_loss: 4.4754e-04
# Epoch 371/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4587e-04 - val_loss: 5.6109e-04
# Epoch 372/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.1319e-04 - val_loss: 5.4458e-04
# Epoch 373/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.2724e-04 - val_loss: 6.3222e-04
# Epoch 374/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.3662e-04 - val_loss: 5.0260e-04
# Epoch 375/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4383e-04 - val_loss: 5.5250e-04
# Epoch 376/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.1510e-04 - val_loss: 4.6707e-04
# Epoch 377/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.4860e-04 - val_loss: 5.5589e-04
# Epoch 378/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.1088e-04 - val_loss: 5.8756e-04
# Epoch 379/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5490e-04 - val_loss: 5.5100e-04
# Epoch 380/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.5395e-04 - val_loss: 5.5487e-04
# Epoch 381/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.3715e-04 - val_loss: 6.6884e-04
# Epoch 382/400
# 136/136 [==============================] - 2s 15ms/step - loss: 3.2133e-04 - val_loss: 5.4272e-04
# Epoch 383/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.2469e-04 - val_loss: 4.9472e-04
# Epoch 384/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.3373e-04 - val_loss: 6.7383e-04
# Epoch 385/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.3511e-04 - val_loss: 6.4633e-04
# Epoch 386/400
# 136/136 [==============================] - 2s 14ms/step - loss: 3.3414e-04 - val_loss: 6.5853e-04
# Epoch 387/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.5872e-04 - val_loss: 6.2446e-04
# Epoch 388/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.2554e-04 - val_loss: 5.0666e-04
# Epoch 389/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.4876e-04 - val_loss: 6.0293e-04
# Epoch 390/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3392e-04 - val_loss: 5.1139e-04
# Epoch 391/400
# 136/136 [==============================] - 2s 13ms/step - loss: 3.3113e-04 - val_loss: 5.0586e-04
# Epoch 392/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3374e-04 - val_loss: 5.4549e-04
# Epoch 393/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.2489e-04 - val_loss: 4.2014e-04
# Epoch 394/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.1880e-04 - val_loss: 5.8193e-04
# Epoch 395/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3101e-04 - val_loss: 5.7221e-04
# Epoch 396/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.2704e-04 - val_loss: 5.3444e-04
# Epoch 397/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.3054e-04 - val_loss: 5.7777e-04
# Epoch 398/400
# 136/136 [==============================] - 2s 12ms/step - loss: 3.5324e-04 - val_loss: 4.7065e-04
# Epoch 399/400
# 136/136 [==============================] - 2s 11ms/step - loss: 3.2788e-04 - val_loss: 5.7097e-04
# Epoch 400/400
# 136/136 [==============================] - 2s 11ms/step - loss: 3.2062e-04 - val_loss: 6.2004e-04

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
# Extracting the loss and validation loss from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Creating epochs range from 1 to 400 (or you can use len(train_loss) if you prefer)
epochs = range(1, len(train_loss) + 1)

# Plotting the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'bo-', label='Training loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
plt.title('Training and Validation Loss (LSTM)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('/kaggle/working/train_validation_LSTM.png')
plt.show()

# %% [markdown]
# ## Training the Model

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 136/136 [==============================] - 2s 4ms/step

# %%
mean_squared_error(y_test,predictions)
# Out:
# 0.000620035560952018

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7618873301719367

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 0.013209724880494444

# %% [markdown]
# # Evaluation on Test Data

# %% [markdown]
# #### Predicting on Brand New Data

# %%
X_test
# Out:
# array([[[0.12121212, 0.28125   , 0.13433962, ..., 0.00809719,
#          0.81818182, 0.        ]],
#
#        [[0.15151515, 0.375     , 0.19698113, ..., 0.00646948,
#          0.63636364, 0.        ]],
#
#        [[0.12121212, 0.3125    , 0.26264151, ..., 0.01037736,
#          0.63636364, 0.        ]],
#
#        ...,
#
#        [[0.12121212, 0.3125    , 0.16181132, ..., 0.00430648,
#          0.81818182, 0.        ]],
#
#        [[0.12121212, 0.21875   , 0.14792453, ..., 0.01045203,
#          1.        , 0.        ]],
#
#        [[0.12121212, 0.3125    , 0.17207547, ..., 0.00614095,
#          1.        , 0.        ]]])

# %%
# Out:
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Out:
# 0.011318139636423682

# %%
# Out:
# 0.0005121437736623032

# %%
# Out:
# 0.8032995122582152

# %%
df['price'].mean()
# Out:
# 540088.1417665294

# %%
df['price'].median()
# Out:
# 450000.0

# %%
# Our predictions
plt.scatter(y_test,predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r', label='LSTM')
# Add labels and legend
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.legend()

# Save the plot
plt.savefig('/kaggle/working/LSTM_sc.png')

# Show the plot
plt.show()

# %%
# Plot perfect predictions line
plt.plot(y_test, y_test, 'r', label='Perfect Predictions')

# Add labels and legend
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.legend()

# Save the plot
plt.savefig('predictions_plot.png')

# Show the plot
plt.show()

# %% [markdown]
# -------------
# ### Predicting on a brand new house

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house = scaler_X.transform(single_house.values.reshape(-1, 19))

# %%
single_house

# %%
df.iloc[0]
